# %% [markdown]
# ## Load datasets
# These cells read the first 5 and last 5 rows of each CSV in `data/raw`, and print total row counts. A streaming approach is used for tails to avoid loading entire large files.

# %%
import pandas as pd
from pathlib import Path
from collections import deque

def head_tail_count(path, n=5, chunksize=100000):
    """Return (head_df, tail_df, total_rows) for CSV at path."""
    # Head: read first n rows (fast)
    head = pd.read_csv(path, nrows=n)
    # Tail and count: stream the file in chunks and keep the last n rows using a deque
    dq = deque(maxlen=n)
    cols = None
    total = 0
    for chunk in pd.read_csv(path, chunksize=chunksize):
        if cols is None:
            cols = chunk.columns
        total += len(chunk)
        dq.extend(chunk.values.tolist())
    tail = pd.DataFrame(list(dq), columns=cols) if cols is not None else pd.DataFrame()
    return head, tail, total

# Example usage for hc3.csv
path = Path(r"c:\\Deep Learning Project\\data\\raw\\hc3.csv")
head, tail, total = head_tail_count(path, n=5)
print('--- hc3.csv: Head ---')
display(head)
print('--- hc3.csv: Tail ---')
display(tail)
print(f'Total rows: {total}')
# Out:
# --- hc3.csv: Head ---
#                                             question  \
# 0  Why is every book I hear about a " NY Times # ...
# 1  If salt is so bad for cars , why do we use it ...
# 2  Why do we still have SD TV channels when HD lo...
# 3  Why has nobody assassinated Kim Jong - un He i...
# 4  How was airplane technology able to advance so...
#
#                                        human_answers  \
# 0  ['Basically there are many categories of " Bes...
# 1  ['salt is good for not dying in car crashes an...
# 2  ["The way it works is that old TV stations got...
# 3  ["You ca n't just go around assassinating the ...
# 4  ['Wanting to kill the shit out of Germans driv...
#
#                                      chatgpt_answers  index       source
# 0  ['There are many different best seller lists t...    NaN  reddit_eli5
# 1  ["Salt is used on roads to help melt ice and s...    NaN  reddit_eli5
# 2  ["There are a few reasons why we still have SD...    NaN  reddit_eli5
# 3  ['It is generally not acceptable or ethical to...    NaN  reddit_eli5
# 4  ['After the Wright Brothers made the first pow...    NaN  reddit_eli5
# --- hc3.csv: Tail ---
#                                             question  \
# 0  Is rise in pressure from 116/66 to 140/80 norm...
# 1  What could cause a painless lump in the right ...
# 2  Can Acutret be given to a child for treatment ...
# 3  Are BP of 119/65 and pulse of 35 causes for co...
# 4  Suggest treatment for back pain after walking ...
#
#                                        human_answers  \
# 0  ['Hello!Welcome and thank you for asking on HC...
# 1  ['Hi, * As per my surgical experience, the iss...
# 2  ['Although it is difficult to comment whether ...
# 3  ['Welcome and thank you for asking on HCM! I h...
# 4  ['Hi,Having this type of back pain at this age...
#
#                                      chatgpt_answers  index    source
# 0  ["It's not uncommon for blood pressure to fluc...    NaN  medicine
# 1  ['There are several possible causes of a painl...    NaN  medicine
# 2  ["It is not appropriate for me to recommend a ...    NaN  medicine
# 3  ['It is not uncommon for people with rheumatoi...    NaN  medicine
# 4  ['It is not uncommon to experience back pain, ...    NaN  medicine
# Total rows: 24322

# %%
# gpt_generated.csv (first 5, last 5, total rows)
path = Path(r"c:\\Deep Learning Project\\data\\raw\\gpt_generated.csv")
head, tail, total = head_tail_count(path, n=5)
print('--- gpt_generated.csv: Head ---')
display(head)
print('--- gpt_generated.csv: Tail ---')
display(tail)
print(f'Total rows: {total}')
# Out:
# --- gpt_generated.csv: Head ---
#   source  id                                               text
# 0  human   0  12 Years a Slave: An Analysis of the Film Essa...
# 1  human   1  20+ Social Media Post Ideas to Radically Simpl...
# 2  human   2  2022 Russian Invasion of Ukraine in Global Med...
# 3  human   3  533 U.S. 27 (2001) Kyllo v. United States: The...
# 4  human   4  A Charles Schwab Corporation Case Essay\n\nCha...
# --- gpt_generated.csv: Tail ---
#   source       id                                               text
# 0     ai  1418649  Today, I accomplished a major feat. I stepped ...
# 1     ai  1418650  As rockets rain down from the sky\nEurope trem...
# 2     ai  1418651  On January 6th, 2023, the world lost a true pi...
# 3     ai  1418652  A gene bank is a repository of genetic materia...
# 4     ai  1418655  On the twelfth day of Christmas, My true love ...
# Total rows: 1392522

# %%
# kaggle_ai_human.csv (first 5, last 5, total rows)
path = Path(r"c:\\Deep Learning Project\\data\\raw\\kaggle_ai_human.csv")
head, tail, total = head_tail_count(path, n=5)
print('--- kaggle_ai_human.csv: Head ---')
display(head)
print('--- kaggle_ai_human.csv: Tail ---')
display(tail)
print(f'Total rows: {total}')
# Out:
# --- kaggle_ai_human.csv: Head ---
#                                                 text  generated
# 0  Cars. Cars have been around since they became ...        0.0
# 1  Transportation is a large necessity in most co...        0.0
# 2  "America's love affair with it's vehicles seem...        0.0
# 3  How often do you ride in a car? Do you drive a...        0.0
# 4  Cars are a wonderful thing. They are perhaps o...        0.0
# --- kaggle_ai_human.csv: Tail ---
#                                                 text  generated
# 0  Tie Face on Mars is really just a big misunder...        0.0
# 1  The whole purpose of democracy is to create a ...        0.0
# 2  I firmly believe that governments worldwide sh...        1.0
# 3  I DFN't agree with this decision because a LFT...        0.0
# 4  Richard Non, Jimmy Carter, and Bob Dole and ot...        0.0
# Total rows: 487235

# %%
# routellm_gpt4_dataset.csv (first 5, last 5, total rows)
path = Path(r"c:\\Deep Learning Project\\data\\raw\\routellm_gpt4_dataset.csv")
head, tail, total = head_tail_count(path, n=5)
print('--- routellm_gpt4_dataset.csv: Head ---')
display(head)
print('--- routellm_gpt4_dataset.csv: Tail ---')
display(tail)
print(f'Total rows: {total}')
# Out:
# --- routellm_gpt4_dataset.csv: Head ---
#                                               prompt             source  \
# 0  I'll give you a review, can you extract the fo...  ['lmsys-chat-1m']
# 1  Answer the following question: Claim: "Joker m...    ['flan_v2_cot']
# 2  TASK DEFINITION: In this task you will be give...   ['flan_v2_niv2']
# 3  Detailed Instructions: In this task, you need ...   ['flan_v2_niv2']
# 4  A guy pick up a woman Then he puts her down Ex...       ['sharegpt']
#
#                                        gpt4_response  \
# 0  Sure, here's the analysis of the review:\n\n1....
# 1  The answer is no.\nChain of thoughts: Stan Lee...
# 2                                ZdoublexpropheciesS
# 3                                                Yes
# 4  This phrase could be interpreted as a joke bec...
#
#                                     mixtral_response  mixtral_score
# 0  Food aspects and opinion words:\n\n1. Made to ...              4
# 1  The answer is no.\n\nChain of thoughts: While ...              5
# 2  ZdoublexpropheciesS\n\nIn this task, you are a...              5
# 3  No, 'station' is not the longest word in the s...              5
# 4  This joke is a play on words and relies on the...              5
# --- routellm_gpt4_dataset.csv: Tail ---
#                                               prompt             source  \
# 0  Research shows that most black people have low...  ['lmsys-chat-1m']
# 1  The script of the film is built around a doctr...  ['lmsys-chat-1m']
# 2  Tell me about revenue development of Microsoft...  ['lmsys-chat-1m']
# 3  I have a youtube video embed. Is there a way t...       ['sharegpt']
# 4   what are good shows for kids like sesame street?   ['anthropic-hh']
#
#                                        gpt4_response  \
# 0  It's important to approach this topic with sen...
# 1  Title: The Book of Purification\n\nChapter 1: ...
# 2  I don't have real-time data, but I can provide...
# 3  Yes, there is a way to hide the channel avatar...
# 4  There are many educational and entertaining sh...
#
#                                     mixtral_response  mixtral_score
# 0  It's important to avoid making sweeping genera...              5
# 1  In the name of the One True God, we welcome yo...              5
# 2  Sure, I'd be happy to help with that! Microsof...              5
# 3  Yes, there is a way to customize the appearanc...              5
# 4  Sure, I'd be happy to help! Here are a few sho...              5
# Total rows: 109101
